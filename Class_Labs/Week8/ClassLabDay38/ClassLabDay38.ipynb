# %% [markdown]
# # Lab Day 38 ~ *Last Lab*

# %% [markdown]
# ## In a jupyter notebook, using the appropriate markdown method include at least one link to a website, news article or blog which discusses ethical issues with computer vision applications and add your personal thoughts and interpretation of this issue.**

# %% [markdown]
# Here is a link to an article that discusses the __[ethical implications of facial recognition technology](https://news.asu.edu/20211117-solutions-ethical-implications-facial-recognition-technology)__.

# %% [markdown]
# In my opinion, the threat to our privacy is going to persist as we are always giving personal data to apps, websites and companies (you can wath this interesting __[documentary](https://www.netflix.com/title/81254224)__ in Netflix), so I don't think adding face recognition will change much the problem.
#
# On the other hand, in case of face recognition for arresting people for example, i think it should be mandatory to have a law to protect individuals against machine mistakes.
#
# Face recognition is not perfect and need to be improve a loty yet - testing on people of different genders, ethnics and ages - so we shouldn't use it for important things such as deciding the innocence/guilt of a person.

# %% [markdown]
# ## Use the https://vision-explorer.allenai.org/text_to_image_generation to generate an image from a caption you provide (choosing a theme from the drop down list), which you should display inside your notebook with the caption you provided and an evaluation of how good a job you feel the machine has done.**

# %%
# %matplotlib inline
from IPython.display import Image
Image('girl.png')

# %% [markdown]
# Theoretically, it should be a *girl drinking water from a black bottle*.
#
# As we can observe here, we can recognisse the girl and maybe the bottle, but no the action of drinking or the colour of the bottle.

# %% [markdown]
# ## Read this blog article. Link the url to your notebook using the appropriate markdown technique and add a summary into your notebook (as markdown) of any image processing steps you saw the author employ.**

# %% [markdown]
# **Blog article link:** __[Dogs vs Cats](https://thedatafrog.com/en/articles/dogs-vs-cats/)__

# %% [markdown]
# **Summary:**
#
# This article explains how to build convolutional neural network from scratch to classify images into two categories, dog or cat, with a 92% accuracy.
#
# The data set consists on images of dogs and cats, and it is famous as it was used for a kaggle competition.
# We need to create two different directories and include all images of dogs in 'dog' and cats in 'cat'.
#
# After having a first look at the dog and cats data sets, we need to start cleanning them. The method is to manually identify the bad images and decide if we should remove them or not. This will improve the queality of the data.
#
# In order nto turn our images into batches of data arrays in memory that can be fed to the network during training, we use Kera's ImageDataGenerator and flow_from_directory. We will get a series of batches with 2 elements where the second one would be the arrays.
#
# As we need to validate the labels of our images, we use a function to plot and automatically label all of them.
#
# Now we will train our neural network on a subset of the dog and cat images called the training dataset, evaluating the performance of the network on a validation dataset , disjoint from the training dataset, to avoid overfitting.
# After compiling the model, we train it on the training dataset, validating the results at the end of each epoch with the validation dataset. In order to see how the training worked, we plot the loss and the accuracy for both the training and validation datasets, as a function of the epoch:
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Some conclusions obtained where the followings:
# - The training accuracy is not able to approach 100% because of the large dropout rate.
# - The network starts overfitting at epoch 6, even with such a large dropout rate.
# - The validation accuracy plateaus around 87%, which is not too bad.
#
# We would need more data to do a better job, so we will use ImageDataGenerator to generate new training examples from the ones we already have.
#
# New loss and accuracy plots:
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# With data augmentation, the training takes longer, but overfitting is much reduced, and we could reach a classification accuracy of 92%.
#
# We can also try using ResNet50, but it didn't work for our classifying purpose.

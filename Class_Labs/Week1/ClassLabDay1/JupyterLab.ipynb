# %% [markdown]
# <div class="alert alert-block alert-info">
# <h1>Jupyter notebook Lab</h1>
# </div>

# %% [markdown]
# ### Table of Contents
#
# * [Purpose](#chapter1)
# * [Your photo](#chapter2)
# * [Seville image](#section_2_1)
# * [List of things to do in Seville](#section_2_2)
# * [Seville video](#video)

# %% [markdown]
# <a class="anchor" id="chapter1"></a>
# _The __purpose__ of this __notebook__ is to show some photos about the perfect destination of a person._

# %%
name = input("What's your name? ")
print("Hi,", name, ".")
# Out:
# What's your name? Luis
# Hi, Luis .

# %% [markdown]
# <a class="anchor" id="chapter2"></a>
# ![6c9d393d273b2f9e04a829153af080f8.png](attachment:6c9d393d273b2f9e04a829153af080f8.png)

# %%
destination = input("Which of these is your favourite destination? ")
# Out:
# Which of these is your favourite destination? Seville

# %% [markdown]
# <a class="anchor" id="section_2_1"></a>
# ![planes-sevilla-puente-noviembre-m.jpg](attachment:planes-sevilla-puente-noviembre-m.jpg)

# %% [markdown]
# <a class="anchor" id="section_2_2"></a>
# <div class="alert alert-block alert-success">
# <h3>In Seville you can:<h3>
#     <li> <span style="color:red">Visit the Cathedral</span></li>
#     <li> <span style="color:blue">Visit the Alcazar</span></li>
#     <li> <span style="color:yellow">Eat tapas</span></li>
# <div>

# %% [markdown]
# <a class="anchor" id="video"></a>
# Here is a link to a video:
# __[Seville in 4K](https://youtu.be/9-PCsRiv6Us)__

# %% [markdown]
# #### I used _alert-success_ for green colour boxes and _alert-info_ for blue colour boxes.
# #### I used _span style_ for changing the colour to the text.
# #### I posted the image by clicking _Edit-Insert image_ and then posting a link to a google image.
# #### Finally, I posted the link to the youtube video using "__[text].(link)__"

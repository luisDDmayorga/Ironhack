# %% [markdown]
# # Lab Customer Analysis - Round 2

# %% [markdown]
# ### 1. Show the dataframe shape.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("marketing_customer_analysis.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
df.shape
# Out:
# (10910, 26)

# %% [markdown]
# ### 2. Standardize header names.

# %%
def standarize_col(col):
    return col.lower().replace(" ", "_")

# %%
new_cols = []
for col in df.columns.to_list():
    new_cols.append(standarize_col(col))

# %%
df.columns = new_cols

# %%
df
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
df = df.rename({'unnamed:_0': 'unnamed'}, axis=1)

# %%
df
# Out:
#        unnamed customer       state  customer_lifetime_value response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# ### 3. Which columns are numerical and which columns are categorical?

# %%
df_numerical = df._get_numeric_data()

# %%
df_categorical = df.drop(columns=df_numerical.columns)

# %% [markdown]
# #### Numerical:

# %%
list(df_numerical.columns)
# Out:
# ['unnamed',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'months_since_last_claim',
#  'months_since_policy_inception',
#  'number_of_open_complaints',
#  'number_of_policies',
#  'total_claim_amount']

# %% [markdown]
# #### Categorical:

# %%
df_categorical.columns.to_list()
# Out:
# ['customer',
#  'state',
#  'response',
#  'coverage',
#  'education',
#  'effective_to_date',
#  'employmentstatus',
#  'gender',
#  'location_code',
#  'marital_status',
#  'policy_type',
#  'policy',
#  'renew_offer_type',
#  'sales_channel',
#  'vehicle_class',
#  'vehicle_size',
#  'vehicle_type']

# %% [markdown]
# ### 4. Check and deal with NaN values.

# %%
nullsdf=pd.DataFrame(round(df.isna().sum()/len(df), 4)*100)
nullsdf.rename(columns={'index':'header',0:'proportionnulls'})
# Out:
#                                proportionnulls
# unnamed                                   0.00
# customer                                  0.00
# state                                     5.78
# customer_lifetime_value                   0.00
# response                                  5.78
# coverage                                  0.00
# education                                 0.00
# effective_to_date                         0.00
# employmentstatus                          0.00
# gender                                    0.00
# income                                    0.00
# location_code                             0.00
# marital_status                            0.00
# monthly_premium_auto                      0.00
# months_since_last_claim                   5.80
# months_since_policy_inception             0.00
# number_of_open_complaints                 5.80
# number_of_policies                        0.00
# policy_type                               0.00
# ...

# %%
df["state"].fillna("Unkown", inplace = True)
df["response"].fillna("Unkown", inplace = True)
df["vehicle_class"].fillna("Unkown", inplace = True)
df["vehicle_size"].fillna("Unkown", inplace = True)
df["vehicle_type"].fillna("Unkown", inplace = True)

# %%
import statistics as stats

# %%
mean_months_since_last_claim = round(stats.mean(df["months_since_last_claim"].dropna()),2)
mean_number_of_open_complaints = round(stats.mean(df["number_of_open_complaints"].dropna()),2)

# %%
df["months_since_last_claim"] = df["months_since_last_claim"].replace(to_replace = np.nan, value = mean_months_since_last_claim)

# %%
df["number_of_open_complaints"] = df["number_of_open_complaints"].replace(to_replace = np.nan, value = mean_number_of_open_complaints)

# %%
df.head()
# Out:
#    unnamed customer       state  customer_lifetime_value response  coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College           2/18/11         Employed      M  ...
# 1   College           1/18/11       Unemployed      F  ...
# 2  Bachelor           2/10/11         Employed      M  ...
# 3   College           1/11/11         Employed      M  ...
# 4  Bachelor           1/17/11    Medical Leave      F  ...
#
#    number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %% [markdown]
# #### Note:

# %% [markdown]
# I change the NaN values in the categorical columns by "Unknwon" and the NaN values in the numerical columns by the mean of the rest of values in the column.

# %% [markdown]
# ### 5. Datetime format - Extract the months from the dataset and store in a separate column. Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.

# %%
import time
from datetime import date

# %%
df['effective_to_date']=pd.to_datetime(df['effective_to_date'], errors = "coerce")

# %%
df['month_number'] = df['effective_to_date'].dt.strftime('%-m')

# %%
df.shape
# Out:
# (10910, 27)

# %%
filtered = df.query('month_number == "1" or month_number == "2" or month_number == "3"')

# %%
filtered.shape
# Out:
# (10910, 27)

# %%
filtered.head()
# Out:
#    unnamed customer       state  customer_lifetime_value response  coverage  \
# 0        0  DK49336     Arizona              4809.216960       No     Basic
# 1        1  KX64629  California              2228.525238       No     Basic
# 2        2  LZ68649  Washington             14947.917300       No     Basic
# 3        3  XL78013      Oregon             22332.439460      Yes  Extended
# 4        4  QA50777      Oregon              9025.067525       No   Premium
#
#   education effective_to_date employmentstatus gender  ...  \
# 0   College        2011-02-18         Employed      M  ...
# 1   College        2011-01-18       Unemployed      F  ...
# 2  Bachelor        2011-02-10         Employed      M  ...
# 3   College        2011-01-11         Employed      M  ...
# 4  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# 0                   9  Corporate Auto  Corporate L3            Offer3
# ...

# %% [markdown]
# ### BONUS: Put all the previously mentioned data transformations into a function.

# %%
data = pd.read_csv("marketing_customer_analysis.csv")

# %%
data.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
def data_trans(data):
    data.columns = new_cols
    data.rename({'unnamed:_0': 'unnamed'}, axis=1)
    data["state"].fillna("Unkown", inplace = True)
    data["response"].fillna("Unkown", inplace = True)
    data["vehicle_class"].fillna("Unkown", inplace = True)
    data["vehicle_size"].fillna("Unkown", inplace = True)
    data["vehicle_type"].fillna("Unkown", inplace = True)
    mean_months_since_last_claim = round(stats.mean(data["months_since_last_claim"].dropna()),2)
    mean_number_of_open_complaints = round(stats.mean(data["number_of_open_complaints"].dropna()),2)
    data["months_since_last_claim"] = data["months_since_last_claim"].replace(to_replace = np.nan, value = mean_months_since_last_claim)
    data["number_of_open_complaints"] = data["number_of_open_complaints"].replace(to_replace = np.nan, value = mean_number_of_open_complaints)
    data['effective_to_date']=pd.to_datetime(data['effective_to_date'], errors = "coerce")
    data['month_number'] = data['effective_to_date'].dt.strftime('%-m')
    data = data.query('month_number == "1" or month_number == "2" or month_number == "3"')
    return data

# %%
data_trans(data)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877      Unkown              6857.519928   Unkown
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...
